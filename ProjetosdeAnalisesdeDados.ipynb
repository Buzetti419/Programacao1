# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
business = pd.read_csv("/content/drive/MyDrive/3.1-data-sheet-udemy-courses-business-courses.csv")
designer = pd.read_csv("/content/drive/MyDrive/3.1-data-sheet-udemy-courses-design-courses.csv")
music = pd.read_csv("/content/drive/MyDrive/3.1-data-sheet-udemy-courses-music-courses.csv")
web = pd.read_csv("/content/drive/MyDrive/3.1-data-sheet-udemy-courses-web-development.csv")

opcao_cursos = pd.concat([business, designer, music, web])

# %%
opcao_cursos
# Out:
#       course_id                                       course_title  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction
# 2      133536.0               Stock Market Investing for Beginners
# 3      151668.0                 Introduction to Financial Modeling
# 4      648826.0         The Complete Financial Analyst Course 2017
# ...         ...                                                ...
# 1200  1227578.0           Learning Path: The Road to Elasticsearch
# 1201  1277924.0                            Angular 4 Front To Back
# 1202  1248172.0            Essentials of Spring 5.0 for Developers
# 1203  1250934.0  Display and analyze GIS data on the web with L...
# 1204  1270222.0  Learning Path: Web Applications with Spring an...
#
#                                                     url  price  \
# 0     https://www.udemy.com/bitcoin-or-how-i-learned...    0.0
# ...

# %%
cursos = opcao_cursos

map()['Unnamed: 0', 'course_id', 'course_title', 'url','price',
     'num_subscribers','num_reviews', 'num_lectures','level','Rating',
     'content_duration', 'published_timestamp','subject'],
    dtype='object')

# %%
opcao_cursos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3681 entries, 0 to 1204
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3676 non-null   float64
#  1   course_title         3676 non-null   object
#  2   url                  3676 non-null   object
#  3   price                3676 non-null   float64
#  4   num_subscribers      3676 non-null   float64
#  5   num_reviews          3676 non-null   float64
#  6   num_lectures         3676 non-null   float64
#  7   level                3676 non-null   object
#  8   Rating               3677 non-null   float64
#  9   content_duration     3676 non-null   float64
#  10  published_timestamp  3676 non-null   object
#  11  subject              3677 non-null   object
# dtypes: float64(7), object(5)
# memory usage: 373.9+ KB

# %%
len(opcao_cursos['course_title'])
# Out:
# 3681

# %%
opcao_cursos['course_title'] = opcao_cursos['course_title'].str.lower()

# %%
opcao_cursos
# Out:
#       course_id                                       course_title  \
# 0       49798.0  Bitcoin or How I Learned to Stop Worrying and ...
# 1       48841.0    Accounting in 60 Minutes - A Brief Introduction
# 2      133536.0               Stock Market Investing for Beginners
# 3      151668.0                 Introduction to Financial Modeling
# 4      648826.0         The Complete Financial Analyst Course 2017
# ...         ...                                                ...
# 1200  1227578.0           Learning Path: The Road to Elasticsearch
# 1201  1277924.0                            Angular 4 Front To Back
# 1202  1248172.0            Essentials of Spring 5.0 for Developers
# 1203  1250934.0  Display and analyze GIS data on the web with L...
# 1204  1270222.0  Learning Path: Web Applications with Spring an...
#
#                                                     url  price  \
# 0     https://www.udemy.com/bitcoin-or-how-i-learned...    0.0
# ...

# %%
opcao_cursos.fillna({'course_title':'vazio'}, inplace=True)

# %%
opcao_cursos[opcao_cursos['course_title'].str.contains('javascript')].shape[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-3253234a733c> in <module>
# ----> 1 opcao_cursos[opcao_cursos['course_title'].str.contains('javascript')].shape[0]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
# -> 3448         if com.is_bool_indexer(key):
#    3449             return self._getitem_bool_array(key)
#    3450
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 139                     raise ValueError(na_msg)
#     140                 return False
#     141             return True
#
# ...

# %%
opcao_cursos["course_title"].str.contains("javascript")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1200    False
# 1201    False
# 1202    False
# 1203    False
# 1204    False
# Name: course_title, Length: 3681, dtype: object

# %%
opcao_cursos['price'].mean()
# Out:
# 66.11534276387377

# %%
round(opcao_cursos['price'].mean(), 2)
# Out:
# 66.12

# %%
opcao_cursos['price'].mean().round(2)
# Out:
# 66.12

# %%
opcao_cursos['price'].describe()
# Out:
# count    3676.000000
# mean       66.115343
# std        61.056073
# min         0.000000
# 25%        20.000000
# 50%        45.000000
# 75%        95.000000
# max       200.000000
# Name: price, dtype: float64

# %%
opcao_cursos['num_subscribers']
# Out:
# 0       65576.0
# 1       56659.0
# 2       50855.0
# 3       29167.0
# 4       24481.0
#          ...
# 1200       50.0
# 1201       44.0
# 1202       34.0
# 1203       25.0
# 1204       19.0
# Name: num_subscribers, Length: 3681, dtype: float64

# %%
opcao_cursos.sort_values("num_subscribers", ascending=False).head(5)[["course_title", "num_subscribers"]]
# Out:
#                                         course_title  num_subscribers
# 0               Learn HTML5 Programming From Scratch         268923.0
# 1                     Coding for Entrepreneurs Basic         161029.0
# 2                         The Web Developer Bootcamp         121584.0
# 3  Build Your First Website in 1 Week with HTML5 ...         120291.0
# 4              The Complete Web Developer Course 2.0         114512.0

# %%
opcao_cursos.sort_values("num_subscribers", ascending=False).head(5)[["Rating"]].describe()
# Out:
#          Rating
# count  5.000000
# mean   0.746000
# std    0.131263
# min    0.550000
# 25%    0.690000
# 50%    0.780000
# 75%    0.820000
# max    0.890000

# %%
opcao_cursos.sort_values("num_subscribers", ascending=False).head(5)[["Rating"]].mean()
# Out:
# Rating    0.746
# dtype: float64

# %%
opcao_cursos.sort_values("num_subscribers", ascending=False).head(5)[["Rating"]].max()
# Out:
# Rating    0.89
# dtype: float64

# %%
opcao_cursos.sort_values("num_subscribers", ascending=False).head(5)[["Rating"]].min()
# Out:
# Rating    0.55
# dtype: float64

# %%
mais_totalizados = opcao_cursos.sort_values("num_reviews", ascending=False).head(10)[["num_reviews", "course_title", "Rating"]]
mais_totalizados
# Out:
#     num_reviews                                       course_title  Rating
# 2       27445.0                         The Web Developer Bootcamp    0.89
# 4       22412.0              The Complete Web Developer Course 2.0    0.55
# 9       19649.0  Angular 4 (formerly Angular 2) - The Complete ...    0.90
# 8       16976.0          JavaScript: Understanding the Weird Parts    0.69
# 21      15117.0                            Modern React with Redux    0.62
# 16      11580.0                     Learn and Understand AngularJS    0.87
# 17      11123.0                        Learn and Understand NodeJS    0.73
# 0        8629.0               Learn HTML5 Programming From Scratch    0.82
# 28       8341.0  Angular 2 with TypeScript for Beginners: The P...    0.74
# 1        7676.0  Pianoforall - Incredible New Way To Learn Pian...    0.96

# %%
lista = opcao_cursos.sort_values('num_reviews', ascending=False).head(10)
mais_inscritos = lista['num_subscribers'].idxmax()
opcao_cursos["course_title"][mais_inscritos]
# Out:
# 0    Bitcoin or How I Learned to Stop Worrying and ...
# 0    Photoshop In-Depth: Master all of Photoshop's ...
# 0                Free Beginner Electric Guitar Lessons
# 0                 Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %%
lista = opcao_cursos.sort_values('num_reviews', ascending=False).head(10)
rate = lista['Rating'].idxmax()
opcao_cursos["course_title"][rate]
# Out:
# 1      Accounting in 60 Minutes - A Brief Introduction
# 1    Figure Drawing From Life Using The Reilly Tech...
# 1    Pianoforall - Incredible New Way To Learn Pian...
# 1                       Coding for Entrepreneurs Basic
# Name: course_title, dtype: object

# %%
opcao_cursos.sort_values("content_duration", ascending=False).head(5)
# Out:
#      course_id                                       course_title  \
# 166   978576.0              The Complete Figure Drawing Course HD
# 266   548278.0  The Complete Web Development Course - Build 15...
# 253   375594.0            Financial Management - A Complete Study
# 727   167316.0            TRADER BOT: Introdução à Linguagem MQL5
# 11     62721.0  Anatomy for Figure Drawing: Mastering the Huma...
#
#                                                    url  price  \
# 166  https://www.udemy.com/the-complete-figure-draw...   50.0
# 266  https://www.udemy.com/complete-web-development...  200.0
# 253  https://www.udemy.com/financial-management-a-c...  190.0
# 727                  https://www.udemy.com/intro-mql5/   20.0
# 11   https://www.udemy.com/anatomy-for-figure-drawi...   95.0
#
#      num_subscribers  num_reviews  num_lectures           level  Rating  \
# 166           1323.0        136.0         225.0  Beginner Level    0.37
# ...

# %%
opcao_cursos['content_duration'].idxmax()
# Out:
# 166

# %%
opcao_cursos.sort_values("num_lectures", ascending=False).head(5)
# Out:
#      course_id                                       course_title  \
# 80     79154.0  Back to School Web Development and Programming...
# 254   543242.0                            Learn to Trade The News
# 998   978728.0  Thoughtful Web Development Course: HTML, Vue.j...
# 253   375594.0            Financial Management - A Complete Study
# 281   481696.0  Code & Grow Rich: Earn More As An Entrepreneur...
#
#                                                    url  price  \
# 80   https://www.udemy.com/back-to-school-web-devel...  200.0
# 254     https://www.udemy.com/learn-to-trade-the-news/  200.0
# 998  https://www.udemy.com/web-development-html5-cs...  200.0
# 253  https://www.udemy.com/financial-management-a-c...  190.0
# 281  https://www.udemy.com/code-grow-rich-earn-more...  200.0
#
#      num_subscribers  num_reviews  num_lectures           level  Rating  \
# 80           18170.0        117.0         779.0      All Levels    0.40
# ...

# %%
aulas = opcao_cursos["num_lectures"].idxmax()
opcao_cursos["course_title"][aulas]
# Out:
# 80    Financial Modeling for Startups & Small Busine...
# 80    Drawing in PowerPoint: Block diagram + Experim...
# 80     Learn to play the piano or keyboard from scratch
# 80    Back to School Web Development and Programming...
# Name: course_title, dtype: object

# %%
opcao_cursos.groupby("level").count()
# Out:
#                     course_id  course_title   url  price  num_subscribers  \
# level
# All Levels               1925          1925  1925   1925             1925
# Beginner Level           1271          1271  1271   1271             1271
# Expert Level               58            58    58     58               58
# Intermediate Level        422           422   422    422              422
#
#                     num_reviews  num_lectures  Rating  content_duration  \
# level
# All Levels                 1925          1925    1925              1925
# Beginner Level             1271          1271    1271              1271
# Expert Level                 58            58      58                58
# Intermediate Level          422           422     422               422
#
#                     published_timestamp  subject
# level
# All Levels                         1925     1925
# Beginner Level                     1271     1271
# Expert Level                         58       58
# ...

# %%
opcao_cursos.groupby("level")["course_id"].count()
# Out:
# level
# All Levels            1925
# Beginner Level        1271
# Expert Level            58
# Intermediate Level     422
# Name: course_id, dtype: int64

# %%
opcao_cursos["published_timestamp"]
# Out:
# 0       2013-04-20T02:25:22Z
# 1       2013-04-07T21:39:25Z
# 2       2013-12-25T19:53:34Z
# 3       2014-05-27T16:22:16Z
# 4       2016-01-21T01:38:48Z
#                 ...
# 1200    2017-05-29T17:56:24Z
# 1201    2017-07-06T15:04:55Z
# 1202    2017-06-11T18:34:40Z
# 1203    2017-06-15T21:17:43Z
# 1204    2017-06-28T21:04:21Z
# Name: published_timestamp, Length: 3681, dtype: object

# %%
opcao_cursos.sort_values('published_timestamp', ascending=False).head(10)[["course_title", "published_timestamp"]]
# Out:
#                                            course_title   published_timestamp
# 1183  Cryptocurrency (BTC & ETH) Investment & Tradin...  2017-07-06T21:46:30Z
# 1164  Forex how traders beat the markest with little...  2017-07-06T21:16:13Z
# 1027  Condor Broken Wing Butterfly Options Trading C...  2017-07-06T19:47:16Z
# 669   ABRSM Grade III Piano Class - Handel Sonatina ...  2017-07-06T16:12:34Z
# 1201                            Angular 4 Front To Back  2017-07-06T15:04:55Z
# 312      Photoshop isn't like what you imagine A to Z .  2017-07-06T03:32:48Z
# 1166  Practical Film Financing: Finding & Pitching I...  2017-07-05T21:46:55Z
# 1142        Bitcoin & Ethereum Course (2 Course Bundle)  2017-07-05T19:06:26Z
# 679                               4 Week Rhythm Mastery  2017-07-05T16:07:44Z
# 1156  Options Trading Foundation: Your journey to co...  2017-07-05T04:41:54Z

# %%
opcao_cursos.groupby(['level', 'subject'])['course_title'].count()
# Out:
# level               subject
# All Levels          Business Finance            633
#                     Graphic Design              335
#                     Musical Instruments         324
#                     Subject: Web Development    633
# Beginner Level      Business Finance            399
#                     Graphic Design              184
#                     Musical Instruments         266
#                     Subject: Web Development    422
# Expert Level        Business Finance             25
#                     Graphic Design                7
#                     Musical Instruments          12
#                     Subject: Web Development     14
# Intermediate Level  Business Finance            134
#                     Graphic Design               76
#                     Musical Instruments          78
#                     Subject: Web Development    134
# Name: course_title, dtype: int64
